# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C3.csv')

# %%
df
# Out:
#      NO                   Name Exam blocks Class  Math  Literature  English  \
# 0     3              Vu Thu An         A00  12C3   9.2         7.7      7.9
# 1    30    Nguyen Tran Yen Chi         B00  12C4   9.0         8.0      7.1
# 2    36     Tran Thi Thu Trinh         B00  12C4   9.7         8.2      7.5
# 3    54        Dam Phuong Dung         A00  12C4   9.3         8.3      7.8
# 4     3              Vu Thu An         A00  12C3   9.2         7.7      7.9
# 5    30    Nguyen Tran Yen Chi         B00  12C4   9.0         8.0      7.1
# 6    36     Tran Thi Thu Trinh         B00  12C4   9.7         8.2      7.5
# 7    66         Pham Viet Dung         D01  12C3   8.6         7.7      8.9
# 8    70     Nguyen Hoang Duong         A01  12C4   9.4         7.5      7.5
# 9    71      Nguyen Ngoc Duong         A00  12C3   7.3         6.6      7.9
# 10   72         Tran Hai Duong         A01  12C4   9.1         7.4      6.9
# ...

# %%
tong = df.iloc[:, 4:11].sum().sum()
print(tong)
# Out:
# 2774.2999999999997

# %%
i = int(input())
print(i)
# Out:
# 51
